# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_values=[120,133,200,220,250]
exp_labels=["blood","sample","F8","buses","car"]

# %%
plt.axis("equal")
plt.pie(exp_values,labels=exp_labels,autopct="%0.1f%%",radius=1,shadow="True",explode=[0,0.2,0,0,0],startangle=100)
plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
