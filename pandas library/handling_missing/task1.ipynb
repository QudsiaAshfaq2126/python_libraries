# %%
import pandas as pd
df=pd.read_csv("weather_data (3).csv",parse_dates=["day"])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_data=df.fillna(0)
new_data
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          0.0        9.0   Sunny
# 2 2017-01-05         28.0        0.0    Snow
# 3 2017-01-06          0.0        7.0       0
# 4 2017-01-07         32.0        0.0    Rain
# 5 2017-01-08          0.0        0.0   Sunny
# 6 2017-01-09          0.0        0.0       0
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_data=df.fillna({
    "temperature":0,
    "windspeed":0,
    "event":"no event"
})
new_data
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01         32.0        6.0      Rain
# 1 2017-01-04          0.0        9.0     Sunny
# 2 2017-01-05         28.0        0.0      Snow
# 3 2017-01-06          0.0        7.0  no event
# 4 2017-01-07         32.0        0.0      Rain
# 5 2017-01-08          0.0        0.0     Sunny
# 6 2017-01-09          0.0        0.0  no event
# 7 2017-01-10         34.0        8.0    Cloudy
# 8 2017-01-11         40.0       12.0     Sunny

# %%
new_data=df.fillna(method="ffill")
new_data
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_7644\2435417302.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_data=df.fillna(method="ffill")
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        7.0   Sunny
# 6 2017-01-09         32.0        7.0   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_data=df.fillna(method="bfill")
new_data
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_7644\712049413.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_data=df.fillna(method="bfill")
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         28.0        9.0   Sunny
# 2 2017-01-05         28.0        7.0    Snow
# 3 2017-01-06         32.0        7.0    Rain
# 4 2017-01-07         32.0        8.0    Rain
# 5 2017-01-08         34.0        8.0   Sunny
# 6 2017-01-09         34.0        8.0  Cloudy
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_data=df.fillna(method="bfill",axis="columns")
new_data
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_7644\1523468732.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_data=df.fillna(method="bfill",axis="columns")
# C:\Users\PC\AppData\Local\Temp\ipykernel_7644\1523468732.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   new_data=df.fillna(method="bfill",axis="columns")
#                    day temperature windspeed   event
# 0  2017-01-01 00:00:00        32.0       6.0    Rain
# 1  2017-01-04 00:00:00         9.0       9.0   Sunny
# 2  2017-01-05 00:00:00        28.0      Snow    Snow
# 3  2017-01-06 00:00:00         7.0       7.0     NaN
# 4  2017-01-07 00:00:00        32.0      Rain    Rain
# ...

# %%
new_data=df.interpolate(method="time")
new_data
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_7644\1854014799.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_data=df.interpolate(method="time")
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 new_data=df.interpolate(method="time")
#       2 new_data
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:8499, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8497 else:
#    8498     index = missing.get_interp_index(method, obj.index)
# -> 8499     new_data = obj._mgr.interpolate(
#    8500         method=method,
#    8501         index=index,
#    8502         limit=limit,
# ...

# %%
new_data=df.dropna(thresh=2)
new_data
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
dt=pd.date_range("01-01-2017","01-11-2017")

idx=pd.DatetimeIndex(dt)
idx
df=df.reindex(idx)
df
# Out:
#            day  temperature  windspeed event
# 2017-01-01 NaT          NaN        NaN   NaN
# 2017-01-02 NaT          NaN        NaN   NaN
# 2017-01-03 NaT          NaN        NaN   NaN
# 2017-01-04 NaT          NaN        NaN   NaN
# 2017-01-05 NaT          NaN        NaN   NaN
# 2017-01-06 NaT          NaN        NaN   NaN
# 2017-01-07 NaT          NaN        NaN   NaN
# 2017-01-08 NaT          NaN        NaN   NaN
# 2017-01-09 NaT          NaN        NaN   NaN
# 2017-01-10 NaT          NaN        NaN   NaN
# 2017-01-11 NaT          NaN        NaN   NaN
