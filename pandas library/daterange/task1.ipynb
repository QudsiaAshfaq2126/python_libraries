# %%
import pandas as pd
df=pd.read_csv("aapl_no_dates.csv")
df.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  153.17  153.33  152.22  153.18  16404088
# 1  153.58  155.45  152.89  155.45  27770715
# 2  154.34  154.45  153.46  153.93  25331662
# 3  153.90  155.81  153.78  154.45  26624926
# 4  155.02  155.98  154.48  155.37  21069647

# %%
eng=pd.date_range(start="6/01/2017",end="6/30/2017",freq="B")
eng
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.set_index("eng",inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16236\4293392457.py in ?()
# ----> 1 df.set_index("eng",inplace=True)
#       2 df
#
# c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['eng'] are in the columns"

# %%
rng = pd.date_range(start="6/01/2017", end="6/30/2017", freq="B")  # Business days
df = pd.DataFrame({"data": range(len(rng))}, index=rng)
df
# Out:
#             data
# 2017-06-01     0
# 2017-06-02     1
# 2017-06-05     2
# 2017-06-06     3
# 2017-06-07     4
# 2017-06-08     5
# 2017-06-09     6
# 2017-06-12     7
# 2017-06-13     8
# 2017-06-14     9
# 2017-06-15    10
# 2017-06-16    11
# 2017-06-19    12
# 2017-06-20    13
# 2017-06-21    14
# 2017-06-22    15
# 2017-06-23    16
# 2017-06-26    17
# 2017-06-27    18
# 2017-06-28    19
# 2017-06-29    20
# 2017-06-30    21

# %%
df = pd.DataFrame({"rng": rng, "data": range(len(rng))})
df.set_index("rng", inplace=True)
df
# Out:
#             data
# rng
# 2017-06-01     0
# 2017-06-02     1
# 2017-06-05     2
# 2017-06-06     3
# 2017-06-07     4
# 2017-06-08     5
# 2017-06-09     6
# 2017-06-12     7
# 2017-06-13     8
# 2017-06-14     9
# 2017-06-15    10
# 2017-06-16    11
# 2017-06-19    12
# 2017-06-20    13
# 2017-06-21    14
# 2017-06-22    15
# 2017-06-23    16
# 2017-06-26    17
# 2017-06-27    18
# 2017-06-28    19
# 2017-06-29    20
# 2017-06-30    21

# %%
df["2017-06-14"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2017-06-14'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df["2017-06-14"]
#
# ...
